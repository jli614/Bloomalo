# %% [markdown]
# <a href="https://colab.research.google.com/github/jli614/Bloomalo/blob/main/Bloomalo_5916_Presentable_Copyt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions on running the Google Colab Notebook:
# From top to bottom, click the play-button to initialize and install the necessary libraries to run the program

# %%
# !pip install beautifulsoup4
# !pip install numpy
# !pip install requests
# !pip install spacy
# !pip install trafilatura
# !pip install nltk
# !pip install pandas
# !pip install tkinter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 8.8 MB/s
# ...
#      |████████████████████████████████| 837 kB 42.4 MB/s
# ...
#      |████████████████████████████████| 140 kB 47.4 MB/s
# ...
#      |████████████████████████████████| 412 kB 49.0 MB/s
# ...
#      |████████████████████████████████| 288 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 749 kB 49.4 MB/s
# ...
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.6.2
#     Uninstalling regex-2022.6.2:
# ...

# %%
from bs4 import BeautifulSoup
import json
import numpy as np
import requests
from requests.models import MissingSchema
import spacy
import trafilatura
import ssl
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
from nltk.stem import WordNetLemmatizer
import openpyxl
from google.colab import drive
drive.mount("/content/gdrive")
import pandas as pd
#pd.read_csv('/content/gdrive/My Drive/sample data/sample.csv')

# This will fail if there is no hyperlink to target
#print(ws.cell(row=2, column=1).hyperlink.target)
nltk.download('omw-1.4')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Mounted at /content/gdrive
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # The results of the below section of code is to produce the currebnt list of URL websites that will form the corpus.

# %%
import re
URL = ["http://aap.org", "http://Brightfutures.aap.org", "https://www.mother.ly/", "http://cdc.gov", "http://Pediatrics.aappublications.org", "http://Psychologytoday.com", "http://www.parents.com", "http://www.atlantaparent.com", "http://www.parenting.com", "http://Kidshealth.org", "http://www.fatherly.com", "http://www.childrensmd.org", "https://www.kckidsdoc.com", "https://www.pediatricsnow.com", "https://www.drgreene.com", "https://blog.cincinnatichildrens.org", "https://www.today.com/parenting-guides", "https://www.babycenter.com", "https://www.more4kids.info", "https://childdevelopmentinfo.com/", "https://www.healthline.com/parenthood",  "https://www.psy-ed.com/wpblog/", "https://developingminds.net.au/blog/" , "https://www.psychologytoday.com/us/basics/child-development",
"https://www.psychologytoday.com/us/basics/adhd/parenting-adhd-child",

"https://www.psychologytoday.com/us/basics/adoption/raising-adopted-child",

"https://www.psychologytoday.com/us/basics/autism/parenting-child-autism",

"https://www.psychologytoday.com/us/blog/how-raise-happy-cooperative-child/201810/ending-homework-battles",

"https://www.psychologytoday.com/us/blog/motivate/201808/how-cure-back-school-anxiety-parents-and-kids",

"https://www.psychologytoday.com/us/blog/all-grown/201808/what-do-if-child-wont-respond-rules-or-consequences",

"https://www.psychologytoday.com/us/articles/199709/praising-your-child",

"https://www.parents.com/baby/development/separation-anxiety/",

"https://www.parents.com/baby/development/intellectual/what-kids-are-scared-of-and-why/",

"https://www.parents.com/parenting/better-parenting/advice/ask-your-mom/my-kids-toddler-tantrums-are-getting-out-of-hand-how-do-i-help-her-express-anger-in-a-healthier-way/",

"https://www.parents.com/recipes/scoop-on-food/simple-ways-to-feed-a-toddler/",

"https://www.parents.com/toddlers-preschoolers/how-to-help-your-kids-adjust-when-they-go-back-to-daycare-and-school-after-covid-19/",

"https://www.parents.com/toddlers-preschoolers/discipline/how-do-i-get-my-toddler-to-stop-telling-me-no/",

"https://www.parents.com/toddlers-preschoolers/discipline/tantrum/a-parents-guide-to-temper-tantrums/",

"https://www.parents.com/health/add-adhd/why-the-key-to-treating-adhd-goes-beyond-medication/",

"https://www.parents.com/toddlers-preschoolers/discipline/tips/7-tips-for-disciplining-your-toddler/",

"https://www.webmd.com/parenting/stop-children-from-biting"


 ]
dictionary = {} # Was originally named dict but https://stackoverflow.com/questions/68691468/jupyter-is-showing-callable-error-in-dict-function?noredirect=1&lq=1
for url in range(len(URL)):
    req = requests.get(URL[url])
    print(URL[url])
    soup = BeautifulSoup(req.text, 'html.parser')
    text = soup.find_all(text=True)
    output = ''
    totalOutput = ''
    blacklist = [
      '[document]',

      'noscript',
        'header',
        'html',
        'meta',
        'head', 
        'input',
        'script',
        'style'
    # there may be more elements you don't want, such as "style", etc.
    ]

    for t in text:
        if t.parent.name not in blacklist and t != '\n':
            output += '{} '.format(t)
            totalOutput +=output
    dictionary[URL[url]] = output.lower()
#print(dictionary)
# Out:
# http://aap.org
# http://Brightfutures.aap.org
# https://www.mother.ly/
# http://cdc.gov
# http://Pediatrics.aappublications.org
# http://Psychologytoday.com
# http://www.parents.com
# http://www.atlantaparent.com
# http://www.parenting.com
# http://Kidshealth.org
# http://www.fatherly.com
# http://www.childrensmd.org
# https://www.kckidsdoc.com
# https://www.pediatricsnow.com
# https://www.drgreene.com
# https://blog.cincinnatichildrens.org
# https://www.today.com/parenting-guides
# https://www.babycenter.com
# https://www.more4kids.info
# https://childdevelopmentinfo.com/
# https://www.healthline.com/parenthood
# https://www.psy-ed.com/wpblog/
# https://developingminds.net.au/blog/
# https://www.psychologytoday.com/us/basics/child-development
# https://www.psychologytoday.com/us/basics/adhd/parenting-adhd-child
# https://www.psychologytoday.com/us/basics/adoption/raising-adopted-child
# https://www.psychologytoday.com/us/basics/autism/parenting-child-autism
# ...

# %%
def stem_keywords():
  keyword = input("Search for a term: ").lower()
  keyword_list_non_stem_tokenize = word_tokenize(keyword)
  stop_words = set(stopwords.words('english'))
  keyword_list_non_stem = [word for word in keyword_list_non_stem_tokenize if word not in stop_words]
  wordnet_lemmatizer = WordNetLemmatizer()
  porter_stemmer  = PorterStemmer()
  keyword_list_stem = []
  for word in keyword_list_non_stem:
    keyword_list_stem.append(porter_stemmer.stem(wordnet_lemmatizer.lemmatize(word)))
  print(keyword_list_stem)
  return keyword_list_stem

# %%
def get_keyword_websites_stemmed(dictionary, keyword_list_stem):
  #url names are key and stemmed lines are values
  keyword_websites_stemmed = {}
  porter_stemmer  = PorterStemmer()

  #gets each key, value pair in dictionary holding url as key and full website text as value 
  for key, value in dictionary.items():

    #get array of each line in the text of the website
    valueList = value.splitlines()
    for line in valueList:
      #print(line)
      for keyword in keyword_list_stem:

        #if keyword is found in line
        if line.find(keyword) != -1:
          if key not in keyword_websites_stemmed:

            #gets stem of each word in text and adds to dictionary
            tokenized_values = word_tokenize(value)

            #print("Tokenized values: " + tokenized_values[0])
            stemmed_values = []
            for word in tokenized_values:
              stemmed_values.append(porter_stemmer.stem(word))
            #print("Stemmed values: " + stemmed_values[0])
            joined_values = ' '.join(stemmed_values)
            keyword_websites_stemmed.update({key: joined_values})
  return keyword_websites_stemmed
            
            #print(joined_values)
          #print("On website: " + key)
          #print(joined_values)
          #print("Keyword is: " + keyword)
      #print(keyword_websites.get('http://aap.org'))

# %% [markdown]
# Below is the desired examination for Jaccard similiary

# %%
#https://goodboychan.github.io/python/datacamp/natural_language_processing/2020/07/17/04-TF-IDF-and-similarity-scores.html#Cosine-similarity
#https://github.com/asvskartheek/Text-Retrieval/blob/master/TF-IDF%20Search%20Engine%20(SKLEARN).ipynb

def print_matches (keyword_list_stem, keyword_websites_stemmed):
  #takes a query, finds cosine similarity between query and rest of websites
  #prints top 10 most similar websites
  from sklearn.metrics.pairwise import cosine_similarity
  from sklearn.feature_extraction.text import TfidfVectorizer
  vectorizer = TfidfVectorizer()
  pd_tfid = pd.DataFrame(list(keyword_websites_stemmed.items()), columns=['url', 'text'])
  #print(pd_tfid)
  X = vectorizer.fit_transform(pd_tfid['text'])
  #print(X.shape)
  joined_keyword_list_stemmed = ' '.join(keyword_list_stem)
  query_vec = vectorizer.transform([joined_keyword_list_stemmed]) 
  results = cosine_similarity(X,query_vec).reshape((-1,)) 
  n = 0
  for i in results.argsort()[-10:][::-1]:
    if(n==0):
      most_similar_website = pd_tfid.iloc[i,0]
    print(pd_tfid.iloc[i,0])
    n = n + 1

  from sklearn.metrics.pairwise import cosine_similarity

# Initialize an instance of tf-idf Vectorizer
  tfidf_vectorizer = TfidfVectorizer()

# Generate the tf-idf vectors for the corpus
  tfidf_matrix = tfidf_vectorizer.fit_transform(keyword_websites_stemmed)

# compute and print the cosine similarity matrix
  cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
  #print(cosine_sim)

  indices = pd.Series(pd_tfid.index, index=pd_tfid['url']).drop_duplicates()
  idx = indices[most_similar_website]
    # Get the pairwsie similarity scores
  sim_scores = list(enumerate(cosine_sim[idx]))
    # Sort the urls based on the similarity scores
  sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=False)
    # Get the scores for 10 most similar urls
  sim_scores = sim_scores[1:11]
    # Get the indices
  url_indices = [i[0] for i in sim_scores]
    # Return the top 10 most similar websites
  print()
  print()
  print("Top result is: ")
  print(most_similar_website)
  print()
  print()
  print("Most dissimilar websites from top result are: ")
  print()
  print(pd_tfid['url'].iloc[url_indices])

  return most_similar_website

# %%
# %pip install py-readability-metrics
from readability import Readability
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
def readability(key, value):
  if not len(value) < 100:
    r = Readability(value)
      
    ari = r.ari()
    print(key)
    #print(ari.score)
    print(ari.grade_levels)
    print(ari.ages)

# %%
#https://stackoverflow.com/questions/56638590/how-to-implement-multi-keyword-search-in-c
keyword_list_stemmed = stem_keywords()
print("Top results for query: ")
keyword_websites_stemmed = get_keyword_websites_stemmed(dictionary, keyword_list_stemmed)
print()
print()
print_matches(keyword_list_stemmed, keyword_websites_stemmed)
print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-00bfe5d898e6> in <module>
#       1 #https://stackoverflow.com/questions/56638590/how-to-implement-multi-keyword-search-in-c
# ----> 2 keyword_list_stemmed = stem_keywords()
#       3 print("Top results for query: ")
#       4 keyword_websites_stemmed = get_keyword_websites_stemmed(dictionary, keyword_list_stemmed)
#       5 print()
#
# <ipython-input-4-ef6703b8ea5f> in stem_keywords()
#       1 def stem_keywords():
# ----> 2   keyword = input("Search for a term: ").lower()
#       3   keyword_list_non_stem_tokenize = word_tokenize(keyword)
#       4   stop_words = set(stopwords.words('english'))
#       5   keyword_list_non_stem = [word for word in keyword_list_non_stem_tokenize if word not in stop_words]
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %% [markdown]
# Not a diagnostic tool...
